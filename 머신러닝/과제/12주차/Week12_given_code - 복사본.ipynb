# %% [markdown]
# # Week12: Deep Learning and TensorFlow

# %% [markdown]
# - **Student ID** : 학번
# - **Name** : 이름

# %% [markdown]
# - Write and run the code below (including Quiz) in jupyter notebook
# - After completion, rename the file, and summit the file to e-class
# - Submit file name : **“Week12_\<StudentID\>_\<Name\>.ipynb”**
#   - Ex) Week12\_2020123456\_홍길동.ipynb
# - Due : **Saturday 11:59pm**

# %%
# pip install pydot
# conda install graphviz

# %% [markdown]
# # 1. Tensorflow Basic

# %% [markdown]
# ## Tensor
# - Tensor is like a multidimensional array
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf

# rank 0 tensor 2
a = None
print(a)

# rank 1 tensor [1, 2]
a = None
print(a)

# rank 2 tensor [[1, 2, 3], [4, 5, 6]]
a = None
print(a)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor([1 2], shape=(2,), dtype=int32)
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %%
# tensor a to numpy array
None
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# type, rank, shape, size of a
print("Type:", None)
print("Rank:", None)
print("Shape:", None)
print("Size:", tf.size(a).numpy())
# Out:
# Type: <dtype: 'int32'>
# Rank: 2
# Shape: (2, 3)
# Size: 6

# %% [markdown]
# ## Operations

# %%
a = tf.constant([[1, 2],
                 [3, 4]])
b = tf.constant([[2, 2],
                 [2, 2]]) 

# element-wise operations on tensors, a + b, a * b
print(None, "\n")
print(None, "\n")
# Out:
# tf.Tensor(
# [[3 4]
#  [5 6]], shape=(2, 2), dtype=int32)
#
# tf.Tensor(
# [[2 4]
#  [6 8]], shape=(2, 2), dtype=int32)

# %%
# matrix multiplication on tensors, a @ b
print(None)
print(None, "\n")
# Out:
# tf.Tensor(
# [[ 6  6]
#  [14 14]], shape=(2, 2), dtype=int32)
# tf.Tensor(
# [[ 6  6]
#  [14 14]], shape=(2, 2), dtype=int32)

# %%
a = tf.constant([[1, 2, 3],
                 [4, 5, 6]], dtype=tf.float32)

# reduce operations on tensors - sum, max
print(None)
print(None)

# reduce operations on axis 0 - sum, mean
print(None)
print(None)
# Out:
# tf.Tensor(21.0, shape=(), dtype=float32)
# tf.Tensor(6.0, shape=(), dtype=float32)
# tf.Tensor([5. 7. 9.], shape=(3,), dtype=float32)
# tf.Tensor([2.5 3.5 4.5], shape=(3,), dtype=float32)

# %%
a = tf.constant([[1, 2, 3],
                 [4, 5, 6]], dtype=tf.float32)
b = tf.constant([[1, 1, 1]], dtype=tf.float32)

# broadcasting a + b
print(None)
# Out:
# tf.Tensor(
# [[2. 3. 4.]
#  [5. 6. 7.]], shape=(2, 3), dtype=float32)

# %% [markdown]
# ## Variables
# - a tensor whose value can be changed by running ops on it. store model parameters such as w and b

# %%
# variable x with initial value [[1, 2], [3, 4]]
w = None

# compute tensor w + 1 
w = None
print(w)
# Out:
# tf.Tensor(
# [[2 3]
#  [4 5]], shape=(2, 2), dtype=int32)

# %% [markdown]
# ## Automatic differentiation
# - **GradientTape** : For automatic differentiation, TensorFlow needs to remember what operations happen in what order during the forward pass.
# - Then, during the backward pass, TensorFlow traverses this list of operations in reverse order to compute gradients.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# variable with initial value 3.0
x = tf.Variable(3.0)

# record operations on tape
with None as tape:
    y = x**2

# compute dy/dx
dy_dx = None

print(dy_dx.numpy())
# Out:
# 6.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variables with initial value 1s and 0s
w = None
b = None

x = tf.constant([[1., 2., 3.]])
y = tf.constant([[4., 8.]])

print("w:\n", w.numpy())
print("b:\n", b.numpy())

# record operations on tape
with None as tape:
    y_hat = None
    loss = None
    
# compute gradients using tape.gradient()
[dl_dw, dl_db] = None

print("y:\n", y.numpy())
print("y_hat:\n", y_hat.numpy())
print("loss:\n", loss.numpy(), "\n")

print("dL/dw:\n", dl_dw.numpy())
print("dL/db:\n", dl_db.numpy())
# Out:
# w:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# b:
#  [[0. 0.]]
# y:
#  [[4. 8.]]
# y_hat:
#  [[6. 6.]]
# loss:
#  4.0
#
# dL/dw:
#  [[ 2. -2.]
#  [ 4. -4.]
#  [ 6. -6.]]
# dL/db:
#  [[ 2. -2.]]

# %% [markdown]
# ### Using optimizer

# %%
# variables with initial value 1s and 0s
w = tf.Variable(tf.ones((3, 2), dtype=tf.float32), name='w')
b = tf.Variable(tf.zeros((1, 2), dtype=tf.float32), name='b')

x = tf.constant([[1., 2., 3.]])
y = tf.constant([[4., 8.]])

print("w:\n", w.numpy())
print("b:\n", b.numpy())

# the loss function
def loss():
    y_hat = x @ w + b
    l = tf.reduce_mean((y_hat - y)**2)
    return l

# use an optimizer SGD
opt = None
 
# 1 step of gradient descent. to minimize loss, update w and b by SGD
None

print("w:\n", w.numpy())
print("b:\n", b.numpy())
# Out:
# w:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# b:
#  [[0. 0.]]
# w:
#  [[0.8        1.2       ]
#  [0.6        1.4       ]
#  [0.39999998 1.6       ]]
# b:
#  [[-0.2  0.2]]

# %% [markdown]
# # 2. Keras : Sequential API

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of building a sequential model 1

# %%
# create sequential model by using add()
# 7 inputs, 1 dense(fully connected) layer with 5 neurons, activation is sigmoid
# 1 dense(fully connected) layer with 4 neurons, activation is sigmoid
model = None

None
None
None

# %%
# display the model
None
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 40
#
#  dense_1 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Example of building a sequential model 2

# %%
# create same sequential model, by providing list of layers
model = keras.Sequential(
    [
        None
        None
        None
    ]
)

# %%
# display the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 5)                 40
#
#  dense_3 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot the model structure
None

# %% [markdown]
# ### Example: XOR style dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

tf.random.set_seed(1)
np.random.seed(1)

# generate random x in [-1, 1]
x = np.random.uniform(low=-1, high=1, size=(100, 2))

# y is 1 if x is in 1st and 3rd quadrant
y = np.ones(len(x))
y[x[:, 0] * x[:, 1] < 0] = 0

fig = plt.figure(figsize=(6, 6))
plt.plot(x[y==0, 0], x[y==0, 1], 'o', color='red')
plt.plot(x[y==1, 0], x[y==1, 1], 'x', color='blue')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# ### Build the model using Keras

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tf.random.set_seed(1)

# create the model structure. 4 layers with units 4, 4, 4, 1. use activation ReLU and Sigmoid

model = keras.Sequential()
None
None
None
None

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 4)                 12
#
#  dense_5 (Dense)             (None, 4)                 20
#
#  dense_6 (Dense)             (None, 4)                 20
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
# compile. use optimizer SGD, loss BinaryCrossentropy
None

# %% [markdown]
# ### Train the model

# %%
# train the model with x, y
hist = None

history = hist.history
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 5ms/step - loss: 0.7353
# Epoch 2/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7162
# Epoch 3/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7014
# Epoch 4/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6947
# Epoch 5/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6928
# Epoch 6/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6921
# Epoch 7/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6917
# Epoch 8/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6915
# Epoch 9/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6913
# Epoch 10/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6911
# Epoch 11/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6907
# Epoch 12/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6904
# Epoch 13/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6901
# Epoch 14/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6896
# Epoch 15/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6894
# Epoch 16/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6888
# Epoch 17/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6886
# Epoch 18/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6885
# Epoch 19/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6879
# Epoch 20/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6875
# Epoch 21/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6871
# Epoch 22/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6866
# Epoch 23/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6861
# Epoch 24/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6856
# Epoch 25/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6850
# Epoch 26/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6845
# Epoch 27/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6838
# Epoch 28/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6833
# Epoch 29/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6824
# Epoch 30/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6817
# Epoch 31/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6808
# Epoch 32/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6801
# Epoch 33/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6790
# Epoch 34/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6781
# Epoch 35/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6769
# Epoch 36/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6757
# Epoch 37/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6745
# Epoch 38/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6727
# Epoch 39/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6710
# Epoch 40/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6683
# Epoch 41/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6655
# Epoch 42/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6628
# Epoch 43/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6603
# Epoch 44/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6568
# Epoch 45/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6530
# Epoch 46/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6485
# Epoch 47/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6429
# Epoch 48/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6370
# Epoch 49/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6302
# Epoch 50/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6234
# Epoch 51/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6157
# Epoch 52/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6079
# Epoch 53/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6001
# Epoch 54/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5924
# Epoch 55/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5847
# Epoch 56/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5764
# Epoch 57/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5685
# Epoch 58/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5611
# Epoch 59/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5530
# Epoch 60/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5455
# Epoch 61/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5384
# Epoch 62/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5310
# Epoch 63/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5238
# Epoch 64/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5172
# Epoch 65/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5108
# Epoch 66/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5032
# Epoch 67/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4970
# Epoch 68/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4901
# Epoch 69/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4828
# Epoch 70/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4768
# Epoch 71/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4698
# Epoch 72/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4628
# Epoch 73/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4594
# Epoch 74/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4531
# Epoch 75/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4481
# Epoch 76/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4430
# Epoch 77/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4382
# Epoch 78/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4319
# Epoch 79/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4296
# Epoch 80/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4247
# Epoch 81/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4202
# Epoch 82/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4162
# Epoch 83/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4098
# Epoch 84/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4027
# Epoch 85/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3971
# Epoch 86/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3880
# Epoch 87/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3787
# Epoch 88/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3737
# Epoch 89/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3642
# Epoch 90/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3500
# Epoch 91/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3378
# Epoch 92/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3230
# Epoch 93/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3136
# Epoch 94/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3009
# Epoch 95/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2819
# Epoch 96/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2697
# Epoch 97/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2506
# Epoch 98/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2335
# Epoch 99/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2193
# Epoch 100/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2036
# Epoch 101/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1928
# Epoch 102/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1799
# Epoch 103/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1697
# Epoch 104/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1647
# Epoch 105/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1538
# Epoch 106/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1460
# Epoch 107/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1424
# Epoch 108/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1345
# Epoch 109/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1315
# Epoch 110/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1218
# Epoch 111/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1218
# Epoch 112/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1166
# Epoch 113/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 114/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1081
# Epoch 115/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1028
# Epoch 116/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0996
# Epoch 117/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0966
# Epoch 118/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0904
# Epoch 119/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0913
# Epoch 120/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0888
# Epoch 121/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 122/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0815
# Epoch 123/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0786
# Epoch 124/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0780
# Epoch 125/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0771
# Epoch 126/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0720
# Epoch 127/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0710
# Epoch 128/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0682
# Epoch 129/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0678
# Epoch 130/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 131/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 132/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0628
# Epoch 133/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0602
# Epoch 134/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0585
# Epoch 135/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0617
# Epoch 136/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0590
# Epoch 137/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0576
# Epoch 138/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0579
# Epoch 139/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0522
# Epoch 140/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0509
# Epoch 141/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0561
# Epoch 142/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0469
# Epoch 143/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0529
# Epoch 144/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0482
# Epoch 145/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0498
# Epoch 146/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0489
# Epoch 147/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0468
# Epoch 148/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0451
# Epoch 149/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0454
# Epoch 150/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0443
# Epoch 151/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0449
# Epoch 152/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0434
# Epoch 153/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 154/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0467
# Epoch 155/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0414
# Epoch 156/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 157/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0355
# Epoch 158/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 159/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0370
# Epoch 160/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0338
# Epoch 161/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 162/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0392
# Epoch 163/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 164/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 165/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 166/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0372
# Epoch 167/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0344
# Epoch 168/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0342
# Epoch 169/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0375
# Epoch 170/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0329
# Epoch 171/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0274
# Epoch 172/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0324
# Epoch 173/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0316
# Epoch 174/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 175/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 176/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 177/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 178/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 179/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 180/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0272
# Epoch 181/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0260
# Epoch 182/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0298
# Epoch 183/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0244
# Epoch 184/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0240
# Epoch 185/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0283
# Epoch 186/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0228
# Epoch 187/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0294
# Epoch 188/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0241
# Epoch 189/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0234
# Epoch 190/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0252
# Epoch 191/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0239
# Epoch 192/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0218
# Epoch 193/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0262
# Epoch 194/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0247
# Epoch 195/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0218
# Epoch 196/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0233
# Epoch 197/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0250
# Epoch 198/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0267
# Epoch 199/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0234
# Epoch 200/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0211

# %%
# show weights of first layer
None
# Out:
# [array([[-1.3076677 ,  1.0514009 ,  0.9045339 , -1.5104895 ],
#         [ 1.5755204 , -0.19498852,  1.9482245 , -0.61444706]],
#        dtype=float32),
#  array([-0.09992066,  0.5411078 ,  0.1885071 , -0.06186164], dtype=float32)]

# %%
# plot the cost. use history.history['loss']
plt.plot(range(1, len(history['loss']) + 1), None)
plt.xlabel('Epoch')
plt.ylabel('Training Cost')

plt.show()

# %% [markdown]
# ### Plot the decision boundary

# %%
# A function for plotting decision regions
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('o', 'x', 's', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=colors[idx], marker=markers[idx], label=cl)

# %%
# plot decision boundary of the model 
plot_decision_regions(x, y, None)

plt.xlabel('x1')
plt.ylabel('x2')
plt.legend(loc='upper left')
plt.show()
# Out:
# 1238/1238 [==============================] - 1s 1ms/step

# %% [markdown]
# ## Saving and loading the model

# %%
# save the model 
None

# %%
# create a model with same structure
new_model = None

new_x = [0.8, 0.8]
y_hat = new_model.predict([new_x])
print(y_hat)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# [[1.]]

# %% [markdown]
# ---

# %% [markdown]
# # 3. Keras : Functional API
# - The Keras functional API is a way to create models that are more flexible than the tf.keras.Sequential API
# - The functional API can handle models with non-linear topology, shared layers, and even multiple inputs or outputs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of building a model with functional API

# %%
from tensorflow import keras
from tensorflow.keras import layers

# inputs with shape (7, ), 
# h1 is outputs(5) of a dense layer with input 'inputs', activation is sigmoid
# outputs is outputs(4) of a dense layer with input 'h1', activation is sigmoid
inputs = None

layer1 = None
h1 = None

layer2 = None
outputs = None

# create a model with inputs=inputs, outputs=outputs
model = None

# %%
# display the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 7)]               0
#
#  dense_8 (Dense)             (None, 5)                 40
#
#  dense_9 (Dense)             (None, 4)                 24
#
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot the model structure
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Example of building more complex model
# ![image-2.png](attachment:image-2.png)

# %%
# input1 (2, ), input2 (5, )
inputs1 = keras.Input(shape=(2,))
inputs2 = keras.Input(shape=(5,))

# h1 is outputs(2) of a dense(fully connected) layer with input 'inputs1'
# h2 is outputs(3) of a dense(fully connected) layer with input 'inputs2'
h1 = layers.Dense(2, activation="sigmoid")(inputs1)
h2 = layers.Dense(3, activation="sigmoid")(inputs2)

# c is a concatenation of h1, h2
c = layers.concatenate([h1, h2])

# outputs1 is outputs(1) of a dense(fully connected) layer with input 'c'
# outputs2 is outputs(10) of a dense(fully connected) layer with input 'c'
outputs1 = layers.Dense(1, activation="sigmoid")(c)
outputs2 = layers.Dense(10, activation="softmax")(c)

# create model with 2 inputs and 2 outputs
model = keras.Model(inputs=[inputs1, inputs2], outputs=[outputs1, outputs2])

# %%
# display the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 2)]          0           []
#
#  input_5 (InputLayer)           [(None, 5)]          0           []
#
#  dense_10 (Dense)               (None, 2)            6           ['input_4[0][0]']
#
#  dense_11 (Dense)               (None, 3)            18          ['input_5[0][0]']
#
#  concatenate (Concatenate)      (None, 5)            0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 1)            6           ['concatenate[0][0]']
#
#  dense_13 (Dense)               (None, 10)           60          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 90
# Trainable params: 90
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# plot the model structure
None

# %% [markdown]
# ---

# %% [markdown]
# # 4. Image Classification using Deep NN with Keras (Sequential API)

# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and prepare the Fashion MNIST dataset

# %%
# read fashion MNIST data 
fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
None
# Out:
# (60000, 28, 28)

# %%
# class labels (y_train)
None
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
plt.imshow(X_train[0], cmap='Greys')
plt.colorbar()
plt.show()

# %%
# names for class labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# name of the class label of train data 0
class_names[y_train[0]]
# Out:
# 'Ankle boot'

# %%
# show first 25 data and label
plt.figure(figsize=(8,8))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
# scaling X
X_train, X_test = None, None

# %% [markdown]
# ### Build the Deep Neural Network model using Keras

# %%
# build the DNN model with flatten input, 2 dense layers with 128 outputs with relu activation,
# 1 dense layers with 10 outputs with softmax activation
model = None

# display the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_14 (Dense)            (None, 128)               100480
#
#  dense_15 (Dense)            (None, 128)               16512
#
#  dense_16 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and Train the model
# Choose an optimizer and loss function for training

# %%
# compile the model with adam optimizer and sparse_categorical_crossentropy loss. metric is accuracy
None

# %%
import time
# checking the execution time
start_time = time.time()

# train the model. use fit(), 20 epoch, batch size 200. record history
history = None

print("Time : ", time.time()-start_time)
# Out:
# Epoch 1/50
# 300/300 [==============================] - 2s 4ms/step - loss: 0.5625 - accuracy: 0.8036
# Epoch 2/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3920 - accuracy: 0.8614
# Epoch 3/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3502 - accuracy: 0.8741
# Epoch 4/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3250 - accuracy: 0.8815
# Epoch 5/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3033 - accuracy: 0.8893
# Epoch 6/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2917 - accuracy: 0.8932
# Epoch 7/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2807 - accuracy: 0.8963
# Epoch 8/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2671 - accuracy: 0.9019
# Epoch 9/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2582 - accuracy: 0.9039
# Epoch 10/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2529 - accuracy: 0.9067
# Epoch 11/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2402 - accuracy: 0.9095
# Epoch 12/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2319 - accuracy: 0.9126
# Epoch 13/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2245 - accuracy: 0.9155
# Epoch 14/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2170 - accuracy: 0.9199
# Epoch 15/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2122 - accuracy: 0.9201
# Epoch 16/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2055 - accuracy: 0.9231
# Epoch 17/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2011 - accuracy: 0.9241
# Epoch 18/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1922 - accuracy: 0.9279
# Epoch 19/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1898 - accuracy: 0.9287
# Epoch 20/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1822 - accuracy: 0.9324
# Epoch 21/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1811 - accuracy: 0.9329
# Epoch 22/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1701 - accuracy: 0.9366
# Epoch 23/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1671 - accuracy: 0.9375
# Epoch 24/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1627 - accuracy: 0.9392
# Epoch 25/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1575 - accuracy: 0.9413
# Epoch 26/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1548 - accuracy: 0.9425
# Epoch 27/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1506 - accuracy: 0.9435
# Epoch 28/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1459 - accuracy: 0.9456
# Epoch 29/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1438 - accuracy: 0.9464
# Epoch 30/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1377 - accuracy: 0.9487
# Epoch 31/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1365 - accuracy: 0.9491
# Epoch 32/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1335 - accuracy: 0.9494
# Epoch 33/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1282 - accuracy: 0.9508
# Epoch 34/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1246 - accuracy: 0.9536
# Epoch 35/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1213 - accuracy: 0.9539
# Epoch 36/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1170 - accuracy: 0.9565
# Epoch 37/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9585
# Epoch 38/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9580
# Epoch 39/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1088 - accuracy: 0.9587
# Epoch 40/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1063 - accuracy: 0.9606
# Epoch 41/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1034 - accuracy: 0.9609
# Epoch 42/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1011 - accuracy: 0.9616
# Epoch 43/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1011 - accuracy: 0.9621
# Epoch 44/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0929 - accuracy: 0.9654
# Epoch 45/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0893 - accuracy: 0.9668
# Epoch 46/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0903 - accuracy: 0.9662
# Epoch 47/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0841 - accuracy: 0.9693
# Epoch 48/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0864 - accuracy: 0.9679
# Epoch 49/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0853 - accuracy: 0.9686
# Epoch 50/50
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0804 - accuracy: 0.9699
# Time :  46.34001636505127

# %% [markdown]
# ### **[Note] Advantage of using GPU**
# - TensorFlow can process large batch sizes quickly through parallel computation using GPUs, so it is much faster than Scikit-learn

# %% [markdown]
# ### Plot the loss

# %%
# plot the loss. use history.history['loss']

plt.plot(history.epoch, None)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
# Train and test accuracy. use evaluate()
loss, acc = None
print('Train accuracy : %.4f' % acc)
loss, acc = None
print('Test accuracy : %.4f' % acc)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0730 - accuracy: 0.9732
# Train accuracy : 0.9732
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4779 - accuracy: 0.8889
# Test accuracy : 0.8889

# %% [markdown]
# ### Make prediction

# %%
# get the predictions of test dataset. use predict()
predictions = None
predictions.shape
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 10)

# %%
# show the image of test data 1
plt.figure(figsize=(1, 1))
plt.imshow(X_test[1], cmap=plt.cm.binary)
plt.show()

# %%
# show the true class name and the predicted class name of test data 1
y_predict = None
print('True lable = %s' % None)
print('Predicted = %s' % None)
# Out:
# True lable = Pullover
# Predicted = Pullover

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 1 : Learning Nonlinear Decision Boundary
# ## Train DNN model with the moon dataset
# - Build the Deep NN model with 100 neurons in 1 hidden layer, 1 neuron in output layer using Keras sequential API
# - Use ReLU for hiden layer and sigmoid for output layer
# - Use Adam optimizer and binary cross entropy
#
# 1. Train the model up to 100 epochs with btach size 10
# 2. Plot the cost change during training
# 3. Show the decision boundary

# %% [markdown]
# ### Dataset

# %%
from sklearn.datasets import make_moons, make_circles
import matplotlib.pyplot as plt

# generate 500 moon data
X, y = None

plt.scatter(X[y==0, 0], X[y==0, 1], c='r')
plt.scatter(X[y==1, 0], X[y==1, 1], c='b')
plt.tight_layout()

plt.show()

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(1)

# create the model structure. 1 hidden layer with 100 units, output layer with 1 unit.
# use activation ReLU and Sigmoid. show model summary
model = None
None
None

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 100)               300
#
#  dense_18 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
# compile. use optimizer Adam, loss BinaryCrossentropy
None

# %% [markdown]
# ### Train the model

# %%
# train the model with X, y. Up to 100 epochs, batch size 10
hist = None

history = hist.history
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6354
# Epoch 2/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4863
# Epoch 3/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3869
# Epoch 4/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3340
# Epoch 5/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3040
# Epoch 6/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2850
# Epoch 7/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2719
# Epoch 8/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2615
# Epoch 9/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2531
# Epoch 10/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2465
# Epoch 11/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2412
# Epoch 12/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2358
# Epoch 13/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2319
# Epoch 14/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2275
# Epoch 15/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2238
# Epoch 16/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2198
# Epoch 17/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2165
# Epoch 18/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2133
# Epoch 19/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2096
# Epoch 20/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2067
# Epoch 21/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2021
# Epoch 22/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1998
# Epoch 23/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1953
# Epoch 24/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1909
# Epoch 25/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1866
# Epoch 26/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1830
# Epoch 27/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1791
# Epoch 28/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1752
# Epoch 29/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1718
# Epoch 30/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1667
# Epoch 31/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1629
# Epoch 32/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1584
# Epoch 33/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1539
# Epoch 34/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1500
# Epoch 35/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1462
# Epoch 36/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1413
# Epoch 37/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1387
# Epoch 38/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1336
# Epoch 39/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1296
# Epoch 40/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1259
# Epoch 41/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1217
# Epoch 42/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1177
# Epoch 43/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1154
# Epoch 44/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1105
# Epoch 45/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1074
# Epoch 46/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1042
# Epoch 47/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1003
# Epoch 48/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0994
# Epoch 49/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0959
# Epoch 50/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0909
# Epoch 51/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0889
# Epoch 52/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0863
# Epoch 53/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0830
# Epoch 54/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0799
# Epoch 55/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 56/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0740
# Epoch 57/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0725
# Epoch 58/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0701
# Epoch 59/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 60/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0645
# Epoch 61/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0618
# Epoch 62/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0591
# Epoch 63/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0571
# Epoch 64/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0555
# Epoch 65/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0528
# Epoch 66/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0506
# Epoch 67/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0489
# Epoch 68/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0464
# Epoch 69/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0448
# Epoch 70/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0433
# Epoch 71/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0416
# Epoch 72/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0399
# Epoch 73/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 74/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0372
# Epoch 75/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0356
# Epoch 76/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 77/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 78/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0319
# Epoch 79/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 80/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 81/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0289
# Epoch 82/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 83/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0269
# Epoch 84/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0258
# Epoch 85/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0256
# Epoch 86/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0243
# Epoch 87/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0233
# Epoch 88/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0226
# Epoch 89/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0219
# Epoch 90/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0215
# Epoch 91/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 92/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0201
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0193
# Epoch 94/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0188
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0184
# Epoch 96/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0180
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 98/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 99/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0164
# Epoch 100/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0158

# %%
# plot the cost. use history.history['loss']
plt.plot(None, None)
plt.xlabel('Epoch')
plt.ylabel('Training Cost')

plt.show()

# %% [markdown]
# ### Plot the decision boundary

# %%
# A function for plotting decision regions
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('o', 'x', 's', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=colors[idx], marker=markers[idx], label=cl)

# %%
# plot decision boundary of the model 
None

plt.xlabel('x1')
plt.ylabel('x2')
plt.legend(loc='upper left')
plt.show()
# Out:
# 1673/1673 [==============================] - 2s 953us/step

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 2 : CIFAR-10 Image Classification using DNN
# - Dataset : CIFAR-10
#    - 32 x 32 x 3 color images (R, G, B)
#    - 10 classes
#
#
# 1. Load the dataset
# 2. Build the DNN model for image classification using Keras
#    - Use 2 hidden layers of 128 neurons each with ReLU activation
# 3. Train the model with Adam optimizer
# 4. Evaluate the model
# 5. Classify test images [1] ~ [10], and show the results

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and prepare the CIFAR-10 dataset
# - 32 x 32 x 3 color images
# - 10 classes
# - 50000 traning data, 10000 test data

# %%
# load CIFAR-10 dataset 
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# check the shape of train and test dataset
None, None
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
# check the labels of train data 0 ~ 4
None
# Out:
# array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)

# %%
# class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# show first 25 train images and labels
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i][0]])
plt.show()

# %% [markdown]
# ### Build DNN model with Keras - Sequential API

# %%
# build the model 
# input shape is (32, 32, 3)
# 1 flatten layer, 2 dense layers with 128 outputs with relu, 1 dense layers with 10 outputs with softmax
model = None

# compile the model with adam optimizer and sparse categorical crossentropy loss
None

# display the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 3072)              0
#
#  dense_19 (Dense)            (None, 128)               393344
#
#  dense_20 (Dense)            (None, 128)               16512
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 411,146
# Trainable params: 411,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# train the model. upto 100 epochs, batch size 256. record history
history = None
# Out:
# Epoch 1/100
# 196/196 [==============================] - 2s 7ms/step - loss: 1.9204 - accuracy: 0.3071 - val_loss: 1.7547 - val_accuracy: 0.3818
# Epoch 2/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.7223 - accuracy: 0.3855 - val_loss: 1.6757 - val_accuracy: 0.4062
# Epoch 3/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.6496 - accuracy: 0.4146 - val_loss: 1.6049 - val_accuracy: 0.4332
# Epoch 4/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.5951 - accuracy: 0.4330 - val_loss: 1.6022 - val_accuracy: 0.4331
# Epoch 5/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5666 - accuracy: 0.4436 - val_loss: 1.5561 - val_accuracy: 0.4464
# Epoch 6/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5296 - accuracy: 0.4554 - val_loss: 1.5230 - val_accuracy: 0.4586
# Epoch 7/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.5039 - accuracy: 0.4635 - val_loss: 1.5496 - val_accuracy: 0.4558
# Epoch 8/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.4790 - accuracy: 0.4745 - val_loss: 1.5839 - val_accuracy: 0.4375
# Epoch 9/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.4618 - accuracy: 0.4817 - val_loss: 1.5021 - val_accuracy: 0.4695
# Epoch 10/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4397 - accuracy: 0.4884 - val_loss: 1.4813 - val_accuracy: 0.4733
# Epoch 11/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4313 - accuracy: 0.4923 - val_loss: 1.4790 - val_accuracy: 0.4768
# Epoch 12/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4138 - accuracy: 0.4979 - val_loss: 1.4594 - val_accuracy: 0.4810
# Epoch 13/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3982 - accuracy: 0.5042 - val_loss: 1.4667 - val_accuracy: 0.4791
# Epoch 14/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.3814 - accuracy: 0.5100 - val_loss: 1.4549 - val_accuracy: 0.4832
# Epoch 15/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.3678 - accuracy: 0.5145 - val_loss: 1.4233 - val_accuracy: 0.4965
# Epoch 16/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.3593 - accuracy: 0.5173 - val_loss: 1.4404 - val_accuracy: 0.4875
# Epoch 17/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.3510 - accuracy: 0.5215 - val_loss: 1.4099 - val_accuracy: 0.4974
# Epoch 18/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3344 - accuracy: 0.5267 - val_loss: 1.4316 - val_accuracy: 0.4922
# Epoch 19/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3242 - accuracy: 0.5319 - val_loss: 1.4538 - val_accuracy: 0.4789
# Epoch 20/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3142 - accuracy: 0.5330 - val_loss: 1.4668 - val_accuracy: 0.4784
# Epoch 21/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3121 - accuracy: 0.5327 - val_loss: 1.4036 - val_accuracy: 0.5015
# Epoch 22/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2947 - accuracy: 0.5403 - val_loss: 1.4203 - val_accuracy: 0.4966
# Epoch 23/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2956 - accuracy: 0.5395 - val_loss: 1.4394 - val_accuracy: 0.4911
# Epoch 24/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2829 - accuracy: 0.5464 - val_loss: 1.4172 - val_accuracy: 0.5018
# Epoch 25/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.2863 - accuracy: 0.5420 - val_loss: 1.4139 - val_accuracy: 0.5020
# Epoch 26/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.2659 - accuracy: 0.5512 - val_loss: 1.3961 - val_accuracy: 0.5028
# Epoch 27/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2671 - accuracy: 0.5500 - val_loss: 1.4460 - val_accuracy: 0.4853
# Epoch 28/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2578 - accuracy: 0.5530 - val_loss: 1.4076 - val_accuracy: 0.5067
# Epoch 29/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2475 - accuracy: 0.5580 - val_loss: 1.3824 - val_accuracy: 0.5130
# Epoch 30/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.2467 - accuracy: 0.5579 - val_loss: 1.4293 - val_accuracy: 0.4964
# Epoch 31/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2404 - accuracy: 0.5591 - val_loss: 1.4022 - val_accuracy: 0.5058
# Epoch 32/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2300 - accuracy: 0.5633 - val_loss: 1.4204 - val_accuracy: 0.4998
# Epoch 33/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2292 - accuracy: 0.5638 - val_loss: 1.4025 - val_accuracy: 0.5064
# Epoch 34/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2269 - accuracy: 0.5642 - val_loss: 1.4673 - val_accuracy: 0.4917
# Epoch 35/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2233 - accuracy: 0.5657 - val_loss: 1.3869 - val_accuracy: 0.5109
# Epoch 36/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2136 - accuracy: 0.5700 - val_loss: 1.4291 - val_accuracy: 0.4973
# Epoch 37/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2074 - accuracy: 0.5714 - val_loss: 1.4071 - val_accuracy: 0.5013
# Epoch 38/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2045 - accuracy: 0.5716 - val_loss: 1.3970 - val_accuracy: 0.5029
# Epoch 39/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.2011 - accuracy: 0.5741 - val_loss: 1.4128 - val_accuracy: 0.5054
# Epoch 40/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.2019 - accuracy: 0.5747 - val_loss: 1.4173 - val_accuracy: 0.5066
# Epoch 41/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1945 - accuracy: 0.5774 - val_loss: 1.4360 - val_accuracy: 0.4967
# Epoch 42/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1843 - accuracy: 0.5781 - val_loss: 1.4215 - val_accuracy: 0.5097
# Epoch 43/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1825 - accuracy: 0.5784 - val_loss: 1.4450 - val_accuracy: 0.4895
# Epoch 44/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1758 - accuracy: 0.5805 - val_loss: 1.4075 - val_accuracy: 0.5083
# Epoch 45/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1690 - accuracy: 0.5822 - val_loss: 1.3967 - val_accuracy: 0.5114
# Epoch 46/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1656 - accuracy: 0.5847 - val_loss: 1.4138 - val_accuracy: 0.5084
# Epoch 47/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1689 - accuracy: 0.5863 - val_loss: 1.3882 - val_accuracy: 0.5154
# Epoch 48/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1650 - accuracy: 0.5871 - val_loss: 1.4044 - val_accuracy: 0.5095
# Epoch 49/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1543 - accuracy: 0.5906 - val_loss: 1.4375 - val_accuracy: 0.5005
# Epoch 50/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1605 - accuracy: 0.5884 - val_loss: 1.4092 - val_accuracy: 0.5118
# Epoch 51/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1604 - accuracy: 0.5877 - val_loss: 1.3980 - val_accuracy: 0.5168
# Epoch 52/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1483 - accuracy: 0.5895 - val_loss: 1.3947 - val_accuracy: 0.5107
# Epoch 53/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1486 - accuracy: 0.5917 - val_loss: 1.3917 - val_accuracy: 0.5139
# Epoch 54/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1421 - accuracy: 0.5934 - val_loss: 1.4069 - val_accuracy: 0.5085
# Epoch 55/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1480 - accuracy: 0.5918 - val_loss: 1.4057 - val_accuracy: 0.5101
# Epoch 56/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1311 - accuracy: 0.5994 - val_loss: 1.4056 - val_accuracy: 0.5092
# Epoch 57/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1319 - accuracy: 0.5986 - val_loss: 1.4281 - val_accuracy: 0.5045
# Epoch 58/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1279 - accuracy: 0.5991 - val_loss: 1.4172 - val_accuracy: 0.5087
# Epoch 59/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1319 - accuracy: 0.5964 - val_loss: 1.4051 - val_accuracy: 0.5115
# Epoch 60/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1231 - accuracy: 0.5998 - val_loss: 1.4263 - val_accuracy: 0.5087
# Epoch 61/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1212 - accuracy: 0.6024 - val_loss: 1.4138 - val_accuracy: 0.5110
# Epoch 62/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1209 - accuracy: 0.5998 - val_loss: 1.4223 - val_accuracy: 0.5054
# Epoch 63/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1226 - accuracy: 0.6007 - val_loss: 1.4081 - val_accuracy: 0.5154
# Epoch 64/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1067 - accuracy: 0.6080 - val_loss: 1.4093 - val_accuracy: 0.5144
# Epoch 65/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1119 - accuracy: 0.6054 - val_loss: 1.4108 - val_accuracy: 0.5153
# Epoch 66/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1097 - accuracy: 0.6053 - val_loss: 1.4233 - val_accuracy: 0.5107
# Epoch 67/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1038 - accuracy: 0.6094 - val_loss: 1.4502 - val_accuracy: 0.5062
# Epoch 68/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.1020 - accuracy: 0.6077 - val_loss: 1.4121 - val_accuracy: 0.5142
# Epoch 69/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0979 - accuracy: 0.6108 - val_loss: 1.4379 - val_accuracy: 0.5088
# Epoch 70/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.1001 - accuracy: 0.6125 - val_loss: 1.4438 - val_accuracy: 0.5012
# Epoch 71/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0920 - accuracy: 0.6139 - val_loss: 1.4308 - val_accuracy: 0.5117
# Epoch 72/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0945 - accuracy: 0.6103 - val_loss: 1.4112 - val_accuracy: 0.5151
# Epoch 73/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0851 - accuracy: 0.6145 - val_loss: 1.4566 - val_accuracy: 0.5022
# Epoch 74/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0937 - accuracy: 0.6102 - val_loss: 1.4661 - val_accuracy: 0.5060
# Epoch 75/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0906 - accuracy: 0.6119 - val_loss: 1.4392 - val_accuracy: 0.5165
# Epoch 76/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0802 - accuracy: 0.6161 - val_loss: 1.4226 - val_accuracy: 0.5193
# Epoch 77/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0776 - accuracy: 0.6177 - val_loss: 1.4467 - val_accuracy: 0.5102
# Epoch 78/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0765 - accuracy: 0.6165 - val_loss: 1.4462 - val_accuracy: 0.5052
# Epoch 79/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0705 - accuracy: 0.6221 - val_loss: 1.4796 - val_accuracy: 0.4979
# Epoch 80/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0733 - accuracy: 0.6184 - val_loss: 1.4375 - val_accuracy: 0.5143
# Epoch 81/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0721 - accuracy: 0.6190 - val_loss: 1.4500 - val_accuracy: 0.5103
# Epoch 82/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0663 - accuracy: 0.6208 - val_loss: 1.4822 - val_accuracy: 0.5057
# Epoch 83/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0693 - accuracy: 0.6196 - val_loss: 1.4436 - val_accuracy: 0.5100
# Epoch 84/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0637 - accuracy: 0.6217 - val_loss: 1.4401 - val_accuracy: 0.5134
# Epoch 85/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0640 - accuracy: 0.6231 - val_loss: 1.4338 - val_accuracy: 0.5149
# Epoch 86/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0589 - accuracy: 0.6225 - val_loss: 1.4736 - val_accuracy: 0.5073
# Epoch 87/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0565 - accuracy: 0.6235 - val_loss: 1.4306 - val_accuracy: 0.5175
# Epoch 88/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0440 - accuracy: 0.6287 - val_loss: 1.4704 - val_accuracy: 0.5004
# Epoch 89/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0508 - accuracy: 0.6262 - val_loss: 1.4607 - val_accuracy: 0.5120
# Epoch 90/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0452 - accuracy: 0.6294 - val_loss: 1.4628 - val_accuracy: 0.5099
# Epoch 91/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0461 - accuracy: 0.6292 - val_loss: 1.4468 - val_accuracy: 0.5168
# Epoch 92/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0377 - accuracy: 0.6323 - val_loss: 1.4931 - val_accuracy: 0.5039
# Epoch 93/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0508 - accuracy: 0.6259 - val_loss: 1.4559 - val_accuracy: 0.5121
# Epoch 94/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0470 - accuracy: 0.6268 - val_loss: 1.4620 - val_accuracy: 0.5100
# Epoch 95/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0390 - accuracy: 0.6298 - val_loss: 1.4520 - val_accuracy: 0.5106
# Epoch 96/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0353 - accuracy: 0.6333 - val_loss: 1.4892 - val_accuracy: 0.5080
# Epoch 97/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0291 - accuracy: 0.6352 - val_loss: 1.4707 - val_accuracy: 0.5099
# Epoch 98/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0337 - accuracy: 0.6324 - val_loss: 1.4981 - val_accuracy: 0.5009
# Epoch 99/100
# 196/196 [==============================] - 1s 5ms/step - loss: 1.0269 - accuracy: 0.6328 - val_loss: 1.4734 - val_accuracy: 0.5081
# Epoch 100/100
# 196/196 [==============================] - 1s 4ms/step - loss: 1.0274 - accuracy: 0.6345 - val_loss: 1.4677 - val_accuracy: 0.5159

# %% [markdown]
# ### Evaluate the model

# %%
# evaluate the model with training data
None
# Out:
# 1563/1563 - 3s - loss: 1.0182 - accuracy: 0.6392 - 3s/epoch - 2ms/step
# [1.0181502103805542, 0.6392199993133545]

# %%
# evaluate the model with test data
None
# Out:
# 313/313 - 1s - loss: 1.4677 - accuracy: 0.5159 - 715ms/epoch - 2ms/step
# [1.4677455425262451, 0.5159000158309937]

# %%
# plot the loss
None

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Classify test images

# %%
# get predictions of test data 0. need reshape to (1, 32, 32, 3)
predictions = None
predictions
# Out:
# 1/1 [==============================] - 0s 43ms/step
# array([[0.0084499 , 0.00698895, 0.00988889, 0.33332795, 0.03549154,
#         0.4951006 , 0.0008747 , 0.0200247 , 0.08930995, 0.00054282]],
#       dtype=float32)

# %%
import numpy as np

# show the classification result of test images 1 ~ 9
for i in range(1, 10):
    plt.figure(figsize=(1,1))
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    plt.show()
    
    prediction = None
    y_predict = None
    None
    None
# Out:
# 1/1 [==============================] - 0s 14ms/step
# True lable = ship
# Predicted = ship
# 1/1 [==============================] - 0s 13ms/step
# True lable = ship
# Predicted = airplane
# 1/1 [==============================] - 0s 14ms/step
# True lable = airplane
# Predicted = ship
# 1/1 [==============================] - 0s 14ms/step
# True lable = frog
# Predicted = deer
# 1/1 [==============================] - 0s 13ms/step
# True lable = frog
# Predicted = frog
# 1/1 [==============================] - 0s 14ms/step
# True lable = automobile
# Predicted = cat
# 1/1 [==============================] - 0s 12ms/step
# True lable = frog
# Predicted = frog
# 1/1 [==============================] - 0s 14ms/step
# True lable = cat
# Predicted = bird
# 1/1 [==============================] - 0s 14ms/step
# True lable = automobile
# Predicted = automobile
