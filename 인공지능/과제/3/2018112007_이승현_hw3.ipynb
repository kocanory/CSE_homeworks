# %%
import numpy as np

N = 9 # the number of training data
X = np.array([[1.0,1.0,0.85,0.76],[1.0,1.0,0.0,0.24],[1.0,0.0,0.625,0.84],
              [1.0,0.0,0.45,0.96],[1.0,1.0,0.225,0.46],[1.0,0.0,0.25,0.7],
              [1.0,1.0,0.7,0.44],[1.0,0.0,0.3,0.4],[1.0,0.0,0.125,0.66]])
y = np.array([1,0,1,1,0,0,1,0,1])
w = np.array([0,0,0,0])
learning_rate = 0.1
iteration = 100

# learning by gradient descent
for i in range(iteration):

    y_hat = X @ w
    loss = 0
    for i in range(N):
        y_hat[i] = 1 / (1 + np.exp(-y_hat[i]))
        loss += pow(y[i] - y_hat[i], 2)
        
    w = w + learning_rate * (X.T @ (y - y_hat))
    print(f'loss = {loss}\n')

# the learned model parameter
print(f'w = {w}\n')

# new data x_tom for tom = (sex=M, age=24, income=2500)
x_tom = np.array([1,1,0.1,0.5])
print(f'x_tom = {x_tom}')

y_tom_hat = x_tom @ w
print(f'y_tom_hat= {y_tom_hat}')
result = 1 / (1 + np.exp(-y_tom_hat))
if result > 0.5:
    print("tom is +")
else:
    print("tom is -")
# Out:
# loss = 2.25
#
# loss = 2.158644158586166
#
# loss = 2.101664976217624
#
# loss = 2.0584220671359277
#
# loss = 2.021206795822304
#
# loss = 1.987145192614945
#
# loss = 1.9551421240408355
#
# loss = 1.9247579050203132
#
# loss = 1.8957937231200466
#
# loss = 1.868138184098286
#
# loss = 1.841711062312591
#
# loss = 1.8164433508381959
#
# loss = 1.792270715091743
#
# loss = 1.7691317192191476
#
# loss = 1.7469676075863105
#
# loss = 1.7257224820936166
#
# loss = 1.7053434907993281
#
# loss = 1.6857809261367886
#
# loss = 1.6669882269871747
#
# loss = 1.6489219058008677
#
# loss = 1.6315414249377846
#
# loss = 1.614809042276326
#
# loss = 1.5986896408866902
#
# loss = 1.5831505530270575
#
# loss = 1.5681613852689344
#
# loss = 1.5536938490815762
#
# loss = 1.5397215994858997
#
# loss = 1.5262200832189106
#
# loss = 1.5131663970673506
#
# loss = 1.500539156514469
#
# loss = 1.4883183745122026
#
# loss = 1.476485349984168
#
# loss = 1.4650225655425508
#
# loss = 1.4539135938367842
#
# loss = 1.4431430119249955
#
# loss = 1.432696323057713
#
# loss = 1.4225598852783259
#
# loss = 1.4127208462702487
#
# loss = 1.4031670839123604
#
# loss = 1.3938871520392224
#
# loss = 1.384870230938792
#
# loss = 1.3761060821565514
#
# loss = 1.3675850072101972
#
# loss = 1.3592978098527713
#
# loss = 1.3512357615539645
#
# loss = 1.34339056989914
#
# loss = 1.3357543496332633
#
# loss = 1.3283195961024699
#
# loss = 1.3210791608694157
#
# loss = 1.3140262292999965
#
# loss = 1.307154299938544
#
# loss = 1.3004571655063584
#
# loss = 1.29392889537455
#
# loss = 1.2875638193767092
#
# loss = 1.2813565128401248
#
# loss = 1.275301782726129
#
# loss = 1.2693946547808888
#
# loss = 1.2636303616075866
#
# loss = 1.25800433157966
#
# loss = 1.252512178522543
#
# loss = 1.2471496920984113
#
# loss = 1.2419128288347374
#
# loss = 1.2367977037431361
#
# loss = 1.2318005824800922
#
# loss = 1.2269178740057312
#
# loss = 1.2221461237009306
#
# loss = 1.2174820069067565
#
# loss = 1.2129223228535444
#
# loss = 1.2084639889499393
#
# loss = 1.204104035404896
#
# loss = 1.1998396001580633
#
# loss = 1.19566792409617
#
# loss = 1.1915863465349723
#
# loss = 1.1875923009481206
#
# loss = 1.1836833109258773
#
# loss = 1.1798569863480783
#
# loss = 1.1761110197570248
#
# loss = 1.1724431829171682
#
# loss = 1.1688513235495264
#
# loss = 1.1653333622297204
#
# loss = 1.161887289439417
#
# loss = 1.1585111627617302
#
# loss = 1.1552031042118787
#
# loss = 1.151961297695046
#
# loss = 1.148783986583974
#
# loss = 1.1456694714093865
#
# loss = 1.14261610765682
#
# loss = 1.1396223036638988
#
# loss = 1.1366865186125021
#
# loss = 1.1338072606106593
#
# loss = 1.1309830848593463
#
# loss = 1.1282125918996821
#
# loss = 1.1254944259363207
#
# loss = 1.122827273233095
#
# loss = 1.1202098605772317
#
# loss = 1.117640953808662
#
# loss = 1.1151193564112034
#
# loss = 1.1126439081625412
#
# loss = 1.1102134838401523
#
# loss = 1.107826991980463
#
# w = [-2.09654683 -0.5129636   3.59533132  2.10489979]
#
# x_tom = [1.  1.  0.1 0.5]
# y_tom_hat= -1.1975273993988913
# tom is -
